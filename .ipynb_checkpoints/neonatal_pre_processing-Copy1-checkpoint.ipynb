# %% [markdown]
# # Machine Learning for disease diagnosis using omics data

# %% [markdown]
# This file and raw data in github repo here: https://github.com/parkyed/sepsis_ml_omics_msc

# %% [markdown]
# # Code:

# %%
import pandas as pd
import numpy as np
import os
from scipy import stats
from collections import OrderedDict
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, roc_auc_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, plot_confusion_matrix
from sklearn.model_selection import KFold, RepeatedKFold
import warnings
from joblib import dump, load
from pickle import dump, load
warnings.filterwarnings(action="ignore", message="^internal gelsd")
warnings.filterwarnings(action="ignore", message="Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.")
#np.random.seed(1)

# %%
os.getcwd()
# Out:
# '/Users/Ed/Documents/GitHub/sepsis_ml_omics_msc'

# %% [markdown]
# ### Data Import

# %%
# import and check data

raw_data = pd.read_csv('genomic_data.csv')
print('The number of columns is:  '+str(len(raw_data.columns)))
print('The number of row is:  '+str(len(raw_data)))
# Out:
# The number of columns is:  93
# The number of row is:  48804

# %% [markdown]
# ### Checking for Duplicates

# %%
# Counting the number of duplicate rows using various columns, NaN values excluded before looking for duplicates.

dup_column = ['NuID', 'Search_Key', 'ILMN_Gene', 'RefSeq_ID', 'Entrez_Gene_ID', 'Probe_Id']
for column in dup_column:
    data = raw_data.dropna(subset=[column])
    dup_list = []
    for index, value in data.duplicated(subset=[column]).items():
        if value == True:
            dup_list.append(index)
    print(f"# duplicate rows based on {column}:   "+str(len(dup_list)))
# Out:
# # duplicate rows based on NuID:   0
# # duplicate rows based on Search_Key:   4671
# # duplicate rows based on ILMN_Gene:   11000
# # duplicate rows based on RefSeq_ID:   5742
# # duplicate rows based on Entrez_Gene_ID:   10897
# # duplicate rows based on Probe_Id:   1

# %%
raw_data.tail(10)
# Out:
#                      NuID       Species   Source   Search_Key   Transcript  \
# 48794  ZZQvowA1A0rdICPUkk  Homo sapiens   RefSeq   ILMN_24212   ILMN_24212
# 48795  ZzTi0SkIUngIr1kHu0  Homo sapiens   RefSeq  ILMN_137958   ILMN_37701
# 48796  ZzTla5Up6pZQklKEU4  Homo sapiens   RefSeq   ILMN_27978   ILMN_27978
# 48797  ZZTZrt5dKGKbmWEeks  Homo sapiens   RefSeq   ILMN_31400   ILMN_31400
# 48798  ZztzUERXUExGBETFFU  Homo sapiens   RefSeq   ILMN_14674   ILMN_14674
# 48799  ZzVW43OPaE6GO1WJqs  Homo sapiens   RefSeq  ILMN_139314  ILMN_139314
# 48800  ZZXgKFKE5q5rp53.p0  Homo sapiens   RefSeq   ILMN_42654   ILMN_42654
# 48801  ZzXXie6icAfD693B6w  Homo sapiens  Unigene  ILMN_104503  ILMN_104503
# 48802  ZzZ5OziA4Anaop_fcU  Homo sapiens   RefSeq   ILMN_14103  ILMN_165051
# 48803                 NaN  Homo sapiens   RefSeq    ILMN_8135    ILMN_8135
#
#        ILMN_Gene Source_Reference_ID    RefSeq_ID Unigene_ID  Entrez_Gene_ID  \
# 48794   CASP8AP2         NM_012115.2  NM_012115.2        NaN          9994.0
# 48795    C20ORF7         NM_024120.3  NM_024120.3        NaN         79133.0
# 48796   TMEM151A         NM_153266.2  NM_153266.2        NaN        256472.0
# 48797  LOC645781         XM_933141.2  XM_933141.2        NaN        645781.0
# 48798      NPY6R         NR_002713.1  NR_002713.1        NaN             NaN
# 48799     SEZ6L2         XM_939114.1  XM_939114.1        NaN         26470.0
# 48800  LOC339047         XM_932631.1  XM_932631.1        NaN        339047.0
# 48801  HS.539415           Hs.539415          NaN  Hs.539415             NaN
# 48802      MAGI1         NM_015520.1  NM_015520.1        NaN          9223.0
# 48803     TUBB2A         NM_001069.2  NM_001069.2        NaN          7280.0
#
#        ...  Inf_149 Inf_152 Inf_157 Inf_159a Inf_162a  Inf_164 Inf_191  \
# 48794  ...   7.0826  7.1113  7.0518   7.0041   7.0160   6.9972  7.1369
# 48795  ...   7.8497  7.7296  7.5873   7.4077   7.4651   7.4088  7.6038
# 48796  ...   7.0177  6.9288  7.0070   6.9190   6.9754   6.9154  7.0130
# 48797  ...   7.1248  7.0515  7.0518   7.1918   7.0641   7.0524  6.9758
# 48798  ...   7.0010  7.0157  6.9841   6.9733   7.0813   7.0127  6.9264
# 48799  ...   7.1036  7.0593  7.0298   7.1770   7.1478   7.0254  7.0245
# 48800  ...   7.0509  7.0305  6.9952   7.0171   7.0033   7.0127  7.1234
# 48801  ...   7.0423  7.0072  7.0298   7.0441   7.0160   7.0254  7.0245
# 48802  ...   7.0423  7.0593  7.1600   7.0308   7.0294   7.0672  7.0606
# 48803  ...      NaN     NaN     NaN      NaN      NaN      NaN     NaN
#
#        Inf_198 Inf_203 Fold change
# 48794   7.0338  7.0494         NaN
# 48795   7.5458  7.5341         NaN
# 48796   7.0644  6.9691         NaN
# 48797   7.0188  7.0494         NaN
# 48798   7.0644  6.9361         NaN
# 48799   6.9904  6.9919         NaN
# 48800   7.0338  7.0380         NaN
# 48801   7.1131  7.0494         NaN
# 48802   7.0644  6.9804         NaN
# 48803      NaN     NaN         NaN
#
# [10 rows x 93 columns]

# %% [markdown]
# ### Drop duplicate rows on Probe_Id and transpose

# %%
# reformat data, drop duplicates, transpose, index on probe_id, drop columns with all NaN, drop Fold change

# drop null value rows
gene_df = raw_data.iloc[:, 0:29]
df = raw_data.iloc[:, np.r_[14, 29:93]].drop_duplicates(subset=['Probe_Id'], keep='first')
df = df.transpose()
df = df.rename(columns=df.iloc[0]).drop(df.index[0])
df = df.drop(['Fold change'], axis=0)
df = df.dropna(axis=1, how='all')

labels = []
for item in df.index:
    if 'Con' in item:
        labels.append(0)
    else:
        labels.append(1)
labels = np.asarray(labels)

bool_series_zeros = (df == 0).all(axis=0)

print('Features:  '+str(len(df.columns)))
print('Examples:  '+str(len(df)))
print('Missing values:   '+str(df.isnull().sum().sum()))
print('The number of columns with all zeros is:   '+str(sum(bool_series_zeros)))
df.head()
# Out:
# Features:  48802
# Examples:  63
# Missing values:   0
# The number of columns with all zeros is:   0
#          ILMN_2227757 ILMN_1683690 ILMN_1710146 ILMN_1822171 ILMN_1748473  \
# Con_001        7.0713       7.0252       7.0713       7.0713      12.8555
# Con_017        7.0033       7.0436       7.0832       7.1232      12.5604
# Con_021        7.0907       7.0323        7.097       7.0824      12.5437
# Con_022b       7.0327        7.024       7.0419        7.024      12.0483
# Con_028        7.0057       6.9538       7.0308       7.0831      12.6549
#
#          ILMN_1822843 ILMN_1710170 ILMN_1704497 ILMN_1847638 ILMN_1772260  \
# Con_001        7.0395       7.0252       7.0252       6.9692       7.1443
# Con_017        7.1232       7.0301       7.1486       6.9203       7.1865
# Con_021        7.0583       7.0739       6.9975       6.9975       7.0405
# Con_022b       7.0766       7.0598       7.1015       6.9954       7.0055
# Con_028        6.9538       6.9538       7.1371       7.1512        7.264
#
#           ... ILMN_1712859 ILMN_1747129 ILMN_1813344 ILMN_2292576  \
# Con_001   ...       6.9278       7.0713       7.6728       7.0545
# Con_017   ...       7.0436       7.0164       8.1798       6.9896
# Con_021   ...        7.097       7.0158       7.8981       7.0158
# Con_022b  ...       7.1564        7.167       7.9036       6.9031
# Con_028   ...       7.0577       7.0057       8.2019       7.0308
#
#          ILMN_1793445 ILMN_2065273 ILMN_1800873 ILMN_1666642 ILMN_1908209  \
# Con_001        7.0103       7.0252       7.2258       7.3808       7.2626
# Con_017        6.9896       7.0963       7.0577       6.9492       7.0164
# Con_021        7.1521       7.0655       7.0824       6.9975        7.097
# Con_022b       7.0598       6.9863       7.1625       7.1378        7.024
# Con_028        7.0702       6.9799       7.0963       7.1512       7.2064
#
#          ILMN_1670343
# Con_001        6.9828
# Con_017        7.0301
# Con_021        6.9892
# Con_022b       7.0327
# Con_028        7.0186
#
# [5 rows x 48802 columns]

# %%
# create copy of the data without patient Inf_075

df_no75 = df.drop(['Inf075'], axis=0)

# re-create labels
labels_no75 = []
for item in df.index:
    if item == 'Inf075':
        continue
    if 'Con' in item:
        labels_no75.append(0)
    else:
        labels_no75.append(1)
labels_no75 = np.asarray(labels_no75)
len(labels_no75)

# check it is correct
#list(zip(df_no75.index, labels_no75))
df_no75.shape
# Out:
# (62, 48802)

# %% [markdown]
# ### Pre-Processing
#
# 1. **Standardisation** - Data standardised (i.e. z-scored) for the following reasons:
# - L1 regularisation penalties in logistic regressions assumes data centred at zero and on the same scale
# - Distance based ML models such as SVM require and assume standardised data, otherwise variables on larger scales disproportionally impact the model
# - Am using the output coeffiecients from logistic regression as a crude measure of feature importance, and so in order to compare coefficients as a measure of relative importance, variables must be standardised
#
# background - https://towardsdatascience.com/normalization-vs-standardization-quantitative-analysis-a91e8a79cebf
#
# 2. **Train, test, split:** 66% train / 33% test
#
# Ref: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %%
# standardise by imputing NaN values and using standard scale - z-scoring
# note - given imputer not necessary, could move standard scaler into the pipeline for each model

def standardise(examples):
    scaler = StandardScaler()
    examples_scaled = scaler.fit_transform(examples)
    return examples_scaled

X_df = standardise(df)
X_df = pd.DataFrame(X_df, columns=df.columns, index=df.index)
print(X_df.shape)

# dataset excluding patient 75
X_df_no75 = standardise(df_no75)
X_df_no75 = pd.DataFrame(X_df_no75, columns=df_no75.columns, index=df_no75.index)
print(X_df_no75.shape)

# Reduced dataset for code testing
X_df_red = X_df.iloc[:, 0:200]
print(X_df_red.shape)
# Out:
# (63, 48802)
# (62, 48802)
# (63, 200)

# %%
# retriving saved results:
import pickle

with open('neonatal_preprocessed.pkl', 'wb') as f:
    pickle.dump([gene_df, X_df, X_df_no75, X_df_red, labels, labels_no75], f)

# %% [markdown]
# ### De-duplicating based on ensembl_gene_id
#
# NOTE: NOT YET DONE, MAY NEED TO GET THE IDS USING R

# %%
# identifying duplicate rows, and elimnating and replacing with max expression levels, across examples.

# drop duplicate 
test_column = 'ILMN_Gene'
full_data = raw_data.drop_duplicates(subset=['Probe_Id'], keep='first')

# get boolean series of duplicates based on test_column name
dd_data = full_data.duplicated(subset=[test_column], keep=False)

# get index of the duplicates - i.e. the ones where True
dup_index = dd_data[dd_data].index

# create new dataframe, dropping all rows in the duplicate index
clean_df = full_data.drop(index=dup_index)

clean_df.sort_values(by=['ILMN_Gene'])
# test to see if there are any further duplicate rows based on that test column
#clean_dups = clean_df.duplicated(subset=['ILMN_Gene'], keep='first')
#print(clean_dups)
#clean_dups[clean_dups].index
# Out:
#                      NuID       Species  Source  Search_Key   Transcript  \
# 25103  Ku8QhfS0n_hIOABXuE  Homo sapiens  RefSeq   ILMN_5579  ILMN_183371
# 29049  NlLnpDrjjo8PUQKCJI  Homo sapiens  RefSeq  ILMN_19974   ILMN_19974
# 42813  Wje_nHHp916e8Akjro  Homo sapiens  RefSeq  ILMN_31305  ILMN_307810
# 47175  ZfoDn4IUQp4Auf56LU  Homo sapiens  RefSeq   ILMN_8023    ILMN_8023
# 7232   97DZJV_gpQpKINl0Ec  Homo sapiens  RefSeq  ILMN_17375   ILMN_17375
# ...                   ...           ...     ...         ...          ...
# 31612  opLIq5393IogH5SiEI  Homo sapiens  RefSeq  ILMN_24644   ILMN_24644
# 252    05KVyf6Big_oj1KLSo  Homo sapiens  RefSeq  ILMN_22056   ILMN_22056
# 15920  EVdUtxU1JfTj09e7Qo  Homo sapiens  RefSeq   ILMN_4827    ILMN_4827
# 24628  KoL5XxK6hf_7w3v91U  Homo sapiens  RefSeq  ILMN_16610   ILMN_16610
# 28926  NKKYJWSJAroBG5cZ7A  Homo sapiens  RefSeq  ILMN_11865   ILMN_11865
#
#       ILMN_Gene Source_Reference_ID       RefSeq_ID Unigene_ID  \
# 25103       7A5         NM_182762.2     NM_182762.2        NaN
# 29049     A26B1         NM_207355.2     NM_207355.2        NaN
# 42813    A26C1B      NM_001099771.1  NM_001099771.1        NaN
# 47175       A2M         NM_000014.4     NM_000014.4        NaN
# 7232      A2ML1         NM_144670.2     NM_144670.2        NaN
# ...         ...                 ...             ...        ...
# 31612     ZUFSP         NM_145062.1     NM_145062.1        NaN
# 252        ZW10         NM_004724.2     NM_004724.2        NaN
# 15920      ZXDB         NM_007157.3     NM_007157.3        NaN
# 24628    ZYG11B         NM_024646.1     NM_024646.1        NaN
# 28926     ZZEF1         NM_015113.3     NM_015113.3        NaN
#
#        Entrez_Gene_ID  ...  Inf_149 Inf_152 Inf_157 Inf_159a Inf_162a  \
# 25103        346389.0  ...   7.0267  6.9027  6.9288   6.9657   7.0408
# 29049        339010.0  ...   7.0348  6.9117  7.0070   7.0041   7.1023
# 42813        728378.0  ...   7.0592  7.0157  7.0641   6.9264   7.0590
# 47175             2.0  ...   6.9565  7.0456  7.0070   7.0510   6.9608
# 7232         144568.0  ...   7.0741  7.1184  7.0750   7.0510   6.9889
# ...               ...  ...      ...     ...     ...      ...      ...
# 31612        221302.0  ...   8.1171  7.7784  7.7894   8.1040   8.1978
# 252            9183.0  ...   7.9831  8.1483  7.9581   7.2240   7.5738
# 15920        158586.0  ...   7.1934  7.1242  7.2487   7.0580   7.0641
# 24628         79699.0  ...   8.0346  8.6077  8.3911   8.4578   8.6710
# 28926         23140.0  ...   7.8563  8.4258  8.2854   7.7498   8.3944
#
#        Inf_164 Inf_191  Inf_198 Inf_203 Fold change
# 25103   6.9972  6.9992   6.9750  7.0849         NaN
# 29049   7.0822  7.0845   7.0491  7.0978         NaN
# 42813   7.1122  7.0724   7.1493  7.0153         NaN
# 47175   7.0524  6.9637   6.9195  7.1239         NaN
# 7232    6.9835  7.0724   7.0491  7.0849         NaN
# ...        ...     ...      ...     ...         ...
# 31612   7.8296  7.7331   7.8357  7.8272         NaN
# 252     7.8844  7.7331   7.6729  7.5341     -0.3903
# 15920   7.1840  7.1504   7.3298  7.1376         NaN
# 24628   8.2491  8.1199   8.1083  8.6916         NaN
# 28926   8.3913  8.4547   8.1570  8.3454         NaN
#
# [30804 rows x 93 columns]

# %%
clean_dups = clean_df.dropna(subset=['Transcript']).duplicated(subset=['Transcript'], keep=False)
dup_index_2 = clean_dups[clean_dups].index
clean_df_2 = clean_df.drop(index=dup_index_2)
clean_df_2
# Out:
#                      NuID       Species   Source   Search_Key   Transcript  \
# 1      0_9dKJSRdZ6nRKsR5o  Homo sapiens   RefSeq   ILMN_42795  ILMN_309061
# 2      0_9Zd7UXqV4FRJ5XdE  Homo sapiens   RefSeq   ILMN_35279   ILMN_35279
# 3      0_CoxIt3fv09UVwOo0  Homo sapiens  Unigene   ILMN_85446   ILMN_85446
# 4      0_DHz7_krTURH3lVHk  Homo sapiens   RefSeq   ILMN_26906   ILMN_26906
# 5      0_dJiKAH3o6kidUsOo  Homo sapiens  Unigene  ILMN_135414  ILMN_135414
# ...                   ...           ...      ...          ...          ...
# 48791  ZzoXZ08Fvp.Kjq6aYk  Homo sapiens  Unigene  ILMN_127410  ILMN_127410
# 48792  ZzQeInuQpqo7l66ISI  Homo sapiens  Unigene  ILMN_106946  ILMN_106946
# 48794  ZZQvowA1A0rdICPUkk  Homo sapiens   RefSeq   ILMN_24212   ILMN_24212
# 48798  ZztzUERXUExGBETFFU  Homo sapiens   RefSeq   ILMN_14674   ILMN_14674
# 48801  ZzXXie6icAfD693B6w  Homo sapiens  Unigene  ILMN_104503  ILMN_104503
#
#        ILMN_Gene Source_Reference_ID       RefSeq_ID Unigene_ID  \
# 1         DCDC2B      NM_001099434.1  NM_001099434.1        NaN
# 2      LOC649978         XM_939064.1     XM_939064.1        NaN
# 3      HS.302418           Hs.302418             NaN  Hs.302418
# 4         GIMAP4         NM_018326.2     NM_018326.2        NaN
# 5      HS.583233           Hs.583233             NaN  Hs.583233
# ...          ...                 ...             ...        ...
# 48791  HS.575229           Hs.575229             NaN  Hs.575229
# 48792  HS.543340           Hs.543340             NaN  Hs.543340
# 48794   CASP8AP2         NM_012115.2     NM_012115.2        NaN
# 48798      NPY6R         NR_002713.1     NR_002713.1        NaN
# 48801  HS.539415           Hs.539415             NaN  Hs.539415
#
#        Entrez_Gene_ID  ...  Inf_149  Inf_152  Inf_157 Inf_159a Inf_162a  \
# 1            149069.0  ...   7.0826   7.0923   7.1350   6.9426   7.0748
# 2            649978.0  ...   7.0010   7.1420   7.1856   7.1013   7.1069
# 3                 NaN  ...   7.0177   7.0861   7.0184   7.0380   6.9952
# 4             55303.0  ...  12.1522  11.0532  12.8357  12.8616  11.9632
# 5                 NaN  ...   7.0665   6.9750   6.9514   7.0041   6.9754
# ...               ...  ...      ...      ...      ...      ...      ...
# 48791             NaN  ...   6.9830   7.1989   7.1112   7.6210   7.5831
# 48792             NaN  ...   7.0348   7.1355   7.0298   7.0171   7.1800
# 48794          9994.0  ...   7.0826   7.1113   7.0518   7.0041   7.0160
# 48798             NaN  ...   7.0010   7.0157   6.9841   6.9733   7.0813
# 48801             NaN  ...   7.0423   7.0072   7.0298   7.0441   7.0160
#
#        Inf_164  Inf_191  Inf_198  Inf_203 Fold change
# 1       6.9416   7.0845   7.0644   7.1239      0.0169
# 2       7.0127   7.0489   7.1493   7.1517      0.0317
# 3       6.9835   7.0963   7.0961   7.0978     -0.0050
# 4      12.6279  10.6621  12.0104  12.0981     -0.6525
# 5       7.1466   6.9992   6.9608   6.9240     -0.0128
# ...        ...      ...      ...      ...         ...
# 48791   7.1840   7.2971   7.1131   7.0041         NaN
# 48792   7.0672   7.1234   6.9608   7.0733         NaN
# 48794   6.9972   7.1369   7.0338   7.0494         NaN
# 48798   7.0127   6.9264   7.0644   6.9361         NaN
# 48801   7.0254   7.0245   7.1131   7.0494         NaN
#
# [30736 rows x 93 columns]
